# %%
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
import pandas as pd

# %%
from utils.data_fetch import read_data
data = read_data()
# Out:
# C:\Users\Vardan\AppData\Local\Temp\ipykernel_8104\1164869249.py:2: DeprecationWarning: [Deprecated][in version 6.0.0]: client_factory will be replaced by gspread.http_client types
#   data = read_data()

# %%
data
# Out:
#     Spindle Speed  Feed (mm/min)  Tool Dia. (mm)  MRR (mm^3 / min)   L_e
# 0          3000.0           10.0             1.0              1.08  0.05
# 1          3000.0           10.0             2.0              3.04  0.32
# 2          3000.0           10.0             3.0              6.41  0.26
# 3          3000.0           15.0             1.0              0.33  0.06
# 4          3000.0           15.0             2.0              5.78  0.23
# 5          3000.0           15.0             3.0              6.03  0.02
# 6          3000.0           20.0             1.0              0.81  0.05
# 7          3000.0           20.0             2.0              4.75  0.01
# 8          3000.0           20.0             3.0             13.24  0.16
# 9          4000.0           10.0             1.0              1.23  0.22
# 10         4000.0           10.0             2.0              2.95  0.12
# 11         4000.0           10.0             3.0              6.73  0.28
# 12         4000.0           15.0             1.0              1.12  0.36
# 13         4000.0           15.0             2.0              3.27  0.25
# 14         4000.0           15.0             3.0             16.87  0.08
# 15         4000.0           20.0             1.0              2.08  0.22
# 16         4000.0           20.0             2.0              6.53  0.09
# 17         4000.0           20.0             3.0             13.34  0.48
# 18         5000.0           10.0             1.0              0.96  0.26
# 19         5000.0           10.0             2.0              5.93  0.13
# 20         5000.0           10.0             3.0              4.91  0.06
# 21         5000.0           15.0             1.0              1.35  0.10
# 22         5000.0           15.0             2.0              4.25  0.07
# 23         5000.0           15.0             3.0              4.31  0.14
# 24         5000.0           20.0             1.0              1.25  0.14
# 25         5000.0           20.0             2.0              5.91  0.25
# 26         5000.0           20.0             3.0              6.86  0.33

# %%
from mpl_toolkits.mplot3d import Axes3D

def plot_3d_contour(data, x_attr, y_attr, z_attr):
    fig = plt.figure(figsize=(8, 6))
    ax = fig.add_subplot(111, projection='3d')

    x = data[x_attr]
    y = data[y_attr]
    z = data[z_attr]

    ax.plot_trisurf(x, y, z, cmap='Greys', edgecolor='none')

    ax.set_xlabel(x_attr)
    ax.set_ylabel(y_attr)
    ax.set_zlabel(z_attr)

    plt.title(f"3D Contour Plot of {x_attr}, {y_attr}, {z_attr}")
    plt.show()

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 27 entries, 0 to 26
# Data columns (total 5 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Spindle Speed     27 non-null     float64
#  1   Feed (mm/min)     27 non-null     float64
#  2   Tool Dia. (mm)    27 non-null     float64
#  3   MRR (mm^3 / min)  27 non-null     float64
#  4   L_e               27 non-null     float64
# dtypes: float64(5)
# memory usage: 1.2 KB

# %%
plot_3d_contour(data, "Spindle Speed", "MRR (mm^3 / min)", "Tool Dia. (mm)")

# %%
import matplotlib.pyplot as plt

def lines_plot(data, x_attr, y_attr, line_attr):
    plt.figure(figsize=(8, 6))

    x = data[x_attr]
    y = data[y_attr]
    lines = data[line_attr]

    for line_value in set(lines):
        x_line = x[lines == line_value]
        y_line = y[lines == line_value]
        plt.plot(x_line, y_line, label=f'{line_attr} {line_value}')

    plt.xlabel(x_attr)
    plt.ylabel(y_attr)
    plt.title(f'Lines based on {line_attr} on {y_attr} vs {x_attr}')
    plt.legend()
    plt.grid(True)
    plt.show()

lines_plot(data,"Spindle Speed", "MRR (mm^3 / min)", "Tool Dia. (mm)")

# %%
lines_plot(data,"Spindle Speed", "L_e", "Tool Dia. (mm)")

# %%
lines_plot(data,"Spindle Speed", "L_e", "Feed (mm/min)")

# %%
! pip install ann_visualizer

# %%
! pip install -r requirements.txt

# %%
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[18], line 1
# ----> 1 from ann_visualizer.visualize import ann_viz
#       3 # Visualize the saved Keras model
#       4 ann_viz('my_model.h5', view=True)
#
# ModuleNotFoundError: No module named 'ann_visualizer'
